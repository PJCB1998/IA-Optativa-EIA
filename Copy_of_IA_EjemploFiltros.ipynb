# %% [markdown]
# <a href="https://colab.research.google.com/github/PJCB1998/IA-Optativa-EIA/blob/main/Copy_of_IA_EjemploFiltros.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import cv2
from google.colab.patches import cv2_imshow
import scipy
from scipy import signal
import matplotlib.pyplot as plt

# %% [markdown]
# # Filtro para buscar bordes

# %%
# !wget https://purepng.com/public/uploads/large/purepng.com-wine-bottleobjectswine-bottlebottle-food-wine-object-drink-alcohol-beverage-liquor-631522325657frobo.png
# Out:
# --2022-10-25 17:46:02--  https://purepng.com/public/uploads/large/purepng.com-wine-bottleobjectswine-bottlebottle-food-wine-object-drink-alcohol-beverage-liquor-631522325657frobo.png
# Resolving purepng.com (purepng.com)... 104.21.42.203, 172.67.210.15, 2606:4700:3031::ac43:d20f, ...
# Connecting to purepng.com (purepng.com)|104.21.42.203|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2123938 (2.0M) [image/png]
# Saving to: ‘purepng.com-wine-bottleobjectswine-bottlebottle-food-wine-object-drink-alcohol-beverage-liquor-631522325657frobo.png.1’
#
# purepng.com-wine-bo 100%[===================>]   2.03M  --.-KB/s    in 0.02s
#
# 2022-10-25 17:46:03 (84.3 MB/s) - ‘purepng.com-wine-bottleobjectswine-bottlebottle-food-wine-object-drink-alcohol-beverage-liquor-631522325657frobo.png.1’ saved [2123938/2123938]

# %%
path='/content/purepng.com-wine-bottleobjectswine-bottlebottle-food-wine-object-drink-alcohol-beverage-liquor-631522325657frobo.png'

# %%
img=cv2.imread(path)
img.shape
# Out:
# (2682, 2000, 3)

# %%
img=cv2.cvtColor(src=img, code=cv2.COLOR_BGR2GRAY) ## Convertir a blanco y negro
imgR=cv2.resize(img,(500,500)) ## Para achicar la imagen un poco
cv2_imshow(imgR)
# Out:
# <PIL.Image.Image image mode=L size=500x500 at 0x7F4034B32810>

# %%
kernel=np.array([[-1,-1,-1],[-1,8,-1],[-1,-1,-1]])
kernel
# Out:
# array([[-1, -1, -1],
#        [-1,  8, -1],
#        [-1, -1, -1]])

# %%
img
# Out:
# array([[255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255],
#        ...,
#        [255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255]], dtype=uint8)

# %%
res=signal.convolve2d(imgR, kernel, mode='same', boundary='fill', fillvalue=0)

# %%
cv2_imshow(res)
# Out:
# <PIL.Image.Image image mode=L size=500x500 at 0x7F4034B428D0>

# %%
kernel=np.array([[1,0,-1],[2,0,-2],[1,0,-1]])
res=signal.convolve2d(imgR, kernel, mode='same', boundary='fill', fillvalue=0)
cv2_imshow(res)
# Out:
# <PIL.Image.Image image mode=L size=500x500 at 0x7F4034291E10>

# %%
kernel=kernel/(np.sum(kernel) if np.sum(kernel)!=0 else 1)
res=cv2.filter2D(imgR, -1,kernel)
cv2_imshow(res)
# Out:
# <PIL.Image.Image image mode=L size=500x500 at 0x7F4034297050>

# %%
kernel=np.array([[1,1,1],[0,0,0],[-1,-1,-1]])
res=signal.convolve2d(imgR, kernel, mode='same', boundary='fill', fillvalue=0)
cv2_imshow(res)
# Out:
# <PIL.Image.Image image mode=L size=500x500 at 0x7F40342979D0>

# %%
img=cv2.imread(path)
img=cv2.cvtColor(src=img,code=cv2.COLOR_BGR2RGB)
imgR=cv2.resize(img,(500,500))
plt.figure(figsize=(10,10))
plt.imshow(imgR)
plt.show()

# %%
kernel=np.array([[1,0,-1],[2,0,-2],[1,0,-1]])
res=cv2.filter2D(imgR, -1,kernel)
plt.figure(figsize=(10,10))
plt.imshow(res)
plt.show()
